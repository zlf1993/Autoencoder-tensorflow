# %%
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
import struct
import os
from tqdm import tqdm
from tqdm import trange
from tensorflow.python.client import device_lib

# %% [markdown]
# ![lables_ubyte_structure](img/labels.png)

# %%
def load_mnist_train(path, kind='train'): 
    labels_path = os.path.join(path, '%s-labels.idx1-ubyte' % kind)
    images_path = os.path.join(path, '%s-images.idx3-ubyte' % kind)
    with open(labels_path, 'rb') as lbpath:
        magic, n = struct.unpack('>II', lbpath.read(8))
        labels = np.fromfile(lbpath,dtype=np.uint8)
    with open(images_path, 'rb') as imgpath: 
        magic, num, rows, cols = struct.unpack('>IIII',imgpath.read(16)) 
        images = np.fromfile(imgpath,dtype=np.uint8).reshape(len(labels), 784)
    
    return images, labels

# %% [markdown]
# ![images_ubyte_structure](img/images.png)

# %%
def load_mnist_test(path, kind='t10k'): 
    labels_path = os.path.join(path,'%s-labels.idx1-ubyte'% kind) 
    images_path = os.path.join(path,'%s-images.idx3-ubyte'% kind) 
    with open(labels_path, 'rb') as lbpath: 
        magic, n = struct.unpack('>II',lbpath.read(8)) 
        labels = np.fromfile(lbpath,dtype=np.uint8) 
    with open(images_path, 'rb') as imgpath: 
        magic, num, rows, cols = struct.unpack('>IIII',imgpath.read(16)) 
        images = np.fromfile(imgpath,dtype=np.uint8).reshape(len(labels), 784)
    
    return images, labels

# %%
def check_available_gpus():
    local_devices = device_lib.list_local_devices()
    gpu_names = [x.name for x in device_lib.list_local_devices() if x.device_type == 'GPU']
    gpu_num = len(gpu_names)
    print('{0} GPUs are detected : {1}'.format(gpu_num, gpu_names))
    return gpu_num

# %%
check_available_gpus()
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# Out:
# 1 GPUs are detected : ['/device:GPU:0']

# %%
path = os.getcwd()
train_images, train_labels = load_mnist_train(path)
test_images, test_labels = load_mnist_test(path)
print(len(train_images))
# Out:
# 60000

# %%
fig = plt.figure(figsize=(8,8))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.5, wspace=0.05)
for i in range(30):
    image = np.reshape(train_images[i],[28,28])
    ax=fig.add_subplot(6,5,i+1,xticks=[],yticks=[]) 
    ax.imshow(image,cmap=plt.cm.binary,interpolation='nearest') 
    ax.text(0,7,str(train_labels[i]))
plt.show()

# %%
train_epochs = 35
batch_size = 5000
noise_factor = 0.5

Input_height = 28
Input_width = 28

input_x = tf.placeholder(tf.float32, shape=[None, Input_height * Input_width], name='input')
input_matrix = tf.reshape(input_x, shape=[-1, Input_height, Input_width, 1])


#encode_processing
#input 28*28
#output 14*14*32
kernal_1 = tf.Variable(tf.truncated_normal(shape=[3,3,1,32], stddev=0.1, name='kernal_1'))
bias_1 = tf.Variable(tf.constant(0.0, shape=[32], name='bias_1'))
conv1 = tf.nn.conv2d(input=input_matrix, filter=kernal_1, strides=[1,1,1,1], padding='SAME')
conv1 = tf.nn.bias_add(conv1, bias_1, name='conv_1')
activ_1 = tf.nn.relu(conv1, name='activ_1')
pool1 = tf.nn.max_pool(value=activ_1, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME', name='max_pool_1')
#pool1 = tf.layers.batch_normalization(pool1)


#input 14*14*32
#output 7*7*32
kernal_2 = tf.Variable(tf.truncated_normal(shape=[3, 3, 32, 32], stddev=0.1, name='kernal_2'))
bias_2 = tf.Variable(tf.constant(0.0, shape=[32], name='bias_2'))
conv2 = tf.nn.conv2d(input=pool1, filter=kernal_2, strides=[1, 1, 1, 1], padding='SAME')
conv2 = tf.nn.bias_add(conv2, bias_2, name='conv_2')
activ_2 = tf.nn.relu(conv2, name='activ_2')
pool2 = tf.nn.max_pool(value=activ_2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME', name='max_pool_2')
#pool2 = tf.layers.batch_normalization(pool2)

#input 7*7*32
#output 4*4*16
kernal_3 = tf.Variable(tf.truncated_normal(shape=[3, 3, 32, 16], stddev=0.1, name='kernal_3'))
bias_3 = tf.Variable(tf.constant(0.0, shape=[16]))
conv3 = tf.nn.conv2d(input=pool2, filter=kernal_3, strides=[1, 1, 1, 1], padding='SAME')
conv3 = tf.nn.bias_add(conv3, bias_3)
activ_3 = tf.nn.relu(conv3, name='activ_3')
pool3 = tf.nn.max_pool(value=activ_3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME', name='max_pool_3')
#pool3 = tf.layers.batch_normalization(pool3)

#input 4*4*16
#output 1*1*64
kernal_4 = tf.Variable(tf.truncated_normal(shape=[4, 4, 16, 64], stddev=0.1, name='kernal_4'))
bias_4 = tf.Variable(tf.constant(0.0, shape=[64]))
conv4 = tf.nn.conv2d(input=pool3, filter=kernal_4, strides=[1, 1, 1, 1], padding='SAME')
conv4 = tf.nn.bias_add(conv4, bias_4)
activ_4 = tf.nn.relu(conv4, name='activ_4')
pool4 = tf.nn.max_pool(value=activ_4, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME', name='max_pool_4')


#decode_processing
deconv_weight_0 = tf.Variable(tf.truncated_normal(shape=[4, 4, 16, 64], stddev=0.1), name='deconv_weight_0')
deconv0 = tf.nn.conv2d_transpose(value=pool4, filter=deconv_weight_0, output_shape=[batch_size, 4, 4, 16], strides=[1, 2, 2, 1], padding='SAME', name='deconv_1')


#input 4*4*16
#output 7*7*32
deconv_weight_1 = tf.Variable(tf.truncated_normal(shape=[3, 3, 32, 16], stddev=0.1), name='deconv_weight_1')
deconv1 = tf.nn.conv2d_transpose(value=pool3, filter=deconv_weight_1, output_shape=[batch_size, 7, 7, 32], strides=[1, 2, 2, 1], padding='SAME', name='deconv_1')

 
## 2 deconv layer
## input 7*7*32
## output 14*14*32
deconv_weight_2 = tf.Variable(tf.truncated_normal(shape=[3, 3,32, 32], stddev=0.1), name='deconv_weight_2')
deconv2 = tf.nn.conv2d_transpose(value=deconv1, filter=deconv_weight_2, output_shape=[batch_size, 14, 14, 32], strides=[1, 2, 2, 1], padding='SAME', name='deconv_2')
 

## 3 deconv layer
## input 14*14*32
## output 28*28*32
deconv_weight_3 = tf.Variable(tf.truncated_normal(shape=[3, 3, 32, 32], stddev=0.1, name='deconv_weight_3'))
deconv3 = tf.nn.conv2d_transpose(value=deconv2, filter=deconv_weight_3, output_shape=[batch_size, 28, 28, 32], strides=[1, 2, 2, 1], padding='SAME', name='deconv_3')


##CONV Layer
##input 28*28*32
##output 28*28*1
weight_final = tf.Variable(tf.truncated_normal(shape=[3, 3, 32, 1], stddev=0.1, name = 'weight_final'))
bias_final = tf.Variable(tf.constant(0.0, shape=[1], name='bias_final'))
conv_final = tf.nn.conv2d(input=deconv3, filter=weight_final, strides=[1, 1, 1, 1], padding='SAME')
conv_final = tf.nn.bias_add(conv_final, bias_final, name='conv_final')

output = tf.reshape(conv_final, shape=[-1,Input_height*Input_width])

loss = tf.reduce_mean(tf.pow(tf.subtract(output, input_x), 2.0),name='loss')
optimizer = tf.train.AdamOptimizer(0.01).minimize(loss)
saver = tf.train.Saver()

# %%
if not os.path.exists('tmp/'):
    os.mkdir('tmp/')

# %%
#Training processing:
with tf.Session() as sess:
    if os.path.exists('tmp/checkpoint'):
        saver.restore(sess, 'tmp/model.ckpt')
    else:
        sess.run(tf.global_variables_initializer())
    total_batch  = int(len(train_images)/batch_size)
    min_lose = float('inf')
    for e in range(train_epochs):    
        for b in tqdm(range(total_batch)):
            batch = train_images[b*batch_size:(b+1)*batch_size]
            imgs = batch.reshape((-1,28,28,1))
            batch_cost, _=sess.run([loss, optimizer],feed_dict={input_x:batch})
            msg = "Global Step={:d}, Local batch={:d}, lose={:.4f}"
            if(batch_cost<min_lose):
                min_lose = batch_cost
                saver.save(sess, 'tmp/model.ckpt')
            print(msg.format(e,b,batch_cost))
# Out:
# INFO:tensorflow:Restoring parameters from tmp/model.ckpt
#   8%|▊         | 1/12 [00:01<00:21,  1.93s/it]
# Global Step=0, Local batch=0, lose=7316.7578
#  17%|█▋        | 2/12 [00:02<00:14,  1.46s/it]
# Global Step=0, Local batch=1, lose=5917.7241
#  25%|██▌       | 3/12 [00:02<00:10,  1.11s/it]
# Global Step=0, Local batch=2, lose=72151.8750
#  33%|███▎      | 4/12 [00:02<00:07,  1.12it/s]
# Global Step=0, Local batch=3, lose=4940.7163
#  42%|████▏     | 5/12 [00:03<00:05,  1.39it/s]
# Global Step=0, Local batch=4, lose=7158.3979
#  50%|█████     | 6/12 [00:03<00:03,  1.69it/s]
# Global Step=0, Local batch=5, lose=7253.7734
#  58%|█████▊    | 7/12 [00:03<00:02,  1.99it/s]
# Global Step=0, Local batch=6, lose=6990.3779
#  67%|██████▋   | 8/12 [00:04<00:01,  2.27it/s]
# Global Step=0, Local batch=7, lose=7314.0225
#  75%|███████▌  | 9/12 [00:04<00:01,  2.51it/s]
# Global Step=0, Local batch=8, lose=7086.6392
#  83%|████████▎ | 10/12 [00:04<00:00,  2.66it/s]
# Global Step=0, Local batch=9, lose=7214.2754
#  92%|█████████▏| 11/12 [00:05<00:00,  2.83it/s]
# Global Step=0, Local batch=10, lose=7077.6167
# 100%|██████████| 12/12 [00:05<00:00,  2.97it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=0, Local batch=11, lose=7192.5986
#   8%|▊         | 1/12 [00:00<00:03,  3.36it/s]
# Global Step=1, Local batch=0, lose=7217.4927
#  17%|█▋        | 2/12 [00:00<00:02,  3.37it/s]
# Global Step=1, Local batch=1, lose=7343.5151
#  25%|██▌       | 3/12 [00:00<00:02,  3.38it/s]
# Global Step=1, Local batch=2, lose=7556.7764
#  33%|███▎      | 4/12 [00:01<00:02,  3.27it/s]
# Global Step=1, Local batch=3, lose=7124.2466
#  42%|████▏     | 5/12 [00:01<00:02,  3.30it/s]
# Global Step=1, Local batch=4, lose=7377.4175
#  50%|█████     | 6/12 [00:01<00:01,  3.32it/s]
# Global Step=1, Local batch=5, lose=7195.5610
#  58%|█████▊    | 7/12 [00:02<00:01,  3.24it/s]
# Global Step=1, Local batch=6, lose=6884.6582
#  67%|██████▋   | 8/12 [00:02<00:01,  3.28it/s]
# Global Step=1, Local batch=7, lose=7036.5078
#  75%|███████▌  | 9/12 [00:02<00:00,  3.29it/s]
# Global Step=1, Local batch=8, lose=6474.3042
#  83%|████████▎ | 10/12 [00:03<00:00,  3.29it/s]
# Global Step=1, Local batch=9, lose=5957.8335
#  92%|█████████▏| 11/12 [00:03<00:00,  3.30it/s]
# Global Step=1, Local batch=10, lose=5249.9199
# 100%|██████████| 12/12 [00:03<00:00,  3.31it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=1, Local batch=11, lose=6563.7671
#   8%|▊         | 1/12 [00:00<00:03,  3.04it/s]
# Global Step=2, Local batch=0, lose=5373.6963
#  17%|█▋        | 2/12 [00:00<00:03,  3.08it/s]
# Global Step=2, Local batch=1, lose=5222.7578
#  25%|██▌       | 3/12 [00:00<00:02,  3.16it/s]
# Global Step=2, Local batch=2, lose=5595.5361
#  33%|███▎      | 4/12 [00:01<00:02,  3.20it/s]
# Global Step=2, Local batch=3, lose=5393.9033
#  42%|████▏     | 5/12 [00:01<00:02,  3.24it/s]
# Global Step=2, Local batch=4, lose=5552.2090
#  50%|█████     | 6/12 [00:01<00:01,  3.22it/s]
# Global Step=2, Local batch=5, lose=5226.8652
#  58%|█████▊    | 7/12 [00:02<00:01,  3.03it/s]
# Global Step=2, Local batch=6, lose=4782.1025
#  67%|██████▋   | 8/12 [00:02<00:01,  2.84it/s]
# Global Step=2, Local batch=7, lose=4772.2905
#  75%|███████▌  | 9/12 [00:02<00:01,  2.90it/s]
# Global Step=2, Local batch=8, lose=4967.2065
#  83%|████████▎ | 10/12 [00:03<00:00,  2.98it/s]
# Global Step=2, Local batch=9, lose=4873.0859
#  92%|█████████▏| 11/12 [00:03<00:00,  2.80it/s]
# Global Step=2, Local batch=10, lose=4504.7266
# 100%|██████████| 12/12 [00:04<00:00,  2.91it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=2, Local batch=11, lose=4561.5845
#   8%|▊         | 1/12 [00:00<00:03,  3.36it/s]
# Global Step=3, Local batch=0, lose=4631.3179
#  17%|█▋        | 2/12 [00:00<00:02,  3.35it/s]
# Global Step=3, Local batch=1, lose=4673.8491
#  25%|██▌       | 3/12 [00:00<00:02,  3.35it/s]
# Global Step=3, Local batch=2, lose=4648.1460
#  33%|███▎      | 4/12 [00:01<00:02,  3.10it/s]
# Global Step=3, Local batch=3, lose=4314.4214
#  42%|████▏     | 5/12 [00:01<00:02,  3.16it/s]
# Global Step=3, Local batch=4, lose=4409.9214
#  50%|█████     | 6/12 [00:01<00:01,  3.17it/s]
# Global Step=3, Local batch=5, lose=4441.8330
#  58%|█████▊    | 7/12 [00:02<00:01,  3.00it/s]
# Global Step=3, Local batch=6, lose=4276.4844
#  67%|██████▋   | 8/12 [00:02<00:01,  2.84it/s]
# Global Step=3, Local batch=7, lose=4214.7012
#  75%|███████▌  | 9/12 [00:03<00:01,  2.77it/s]
# Global Step=3, Local batch=8, lose=4142.7510
#  83%|████████▎ | 10/12 [00:03<00:00,  2.92it/s]
# Global Step=3, Local batch=9, lose=4245.8545
#  92%|█████████▏| 11/12 [00:03<00:00,  2.84it/s]
# Global Step=3, Local batch=10, lose=4100.6416
# 100%|██████████| 12/12 [00:04<00:00,  2.78it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=3, Local batch=11, lose=4069.0430
#   8%|▊         | 1/12 [00:00<00:04,  2.57it/s]
# Global Step=4, Local batch=0, lose=4049.6182
#  17%|█▋        | 2/12 [00:00<00:03,  2.56it/s]
# Global Step=4, Local batch=1, lose=4037.8464
#  25%|██▌       | 3/12 [00:01<00:03,  2.53it/s]
# Global Step=4, Local batch=2, lose=4024.5454
#  33%|███▎      | 4/12 [00:01<00:03,  2.51it/s]
# Global Step=4, Local batch=3, lose=3946.1816
#  42%|████▏     | 5/12 [00:01<00:02,  2.70it/s]
# Global Step=4, Local batch=4, lose=4000.1755
#  50%|█████     | 6/12 [00:02<00:02,  2.67it/s]
# Global Step=4, Local batch=5, lose=3914.1323
#  58%|█████▊    | 7/12 [00:02<00:01,  2.64it/s]
# Global Step=4, Local batch=6, lose=3818.1411
#  67%|██████▋   | 8/12 [00:02<00:01,  2.81it/s]
# Global Step=4, Local batch=7, lose=3874.6475
#  75%|███████▌  | 9/12 [00:03<00:01,  2.78it/s]
# Global Step=4, Local batch=8, lose=3794.3601
#  83%|████████▎ | 10/12 [00:03<00:00,  2.91it/s]
# Global Step=4, Local batch=9, lose=3829.6116
#  92%|█████████▏| 11/12 [00:04<00:00,  2.82it/s]
# Global Step=4, Local batch=10, lose=3749.4421
# 100%|██████████| 12/12 [00:04<00:00,  2.92it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=4, Local batch=11, lose=3777.5513
#   8%|▊         | 1/12 [00:00<00:04,  2.59it/s]
# Global Step=5, Local batch=0, lose=3724.0850
#  17%|█▋        | 2/12 [00:00<00:04,  2.49it/s]
# Global Step=5, Local batch=1, lose=3684.5005
#  25%|██▌       | 3/12 [00:01<00:03,  2.70it/s]
# Global Step=5, Local batch=2, lose=3714.3286
#  33%|███▎      | 4/12 [00:01<00:02,  2.67it/s]
# Global Step=5, Local batch=3, lose=3622.1309
#  42%|████▏     | 5/12 [00:01<00:02,  2.83it/s]
# Global Step=5, Local batch=4, lose=3642.3320
#  50%|█████     | 6/12 [00:02<00:02,  2.75it/s]
# Global Step=5, Local batch=5, lose=3580.9514
#  58%|█████▊    | 7/12 [00:02<00:01,  2.70it/s]
# Global Step=5, Local batch=6, lose=3500.3501
#  67%|██████▋   | 8/12 [00:02<00:01,  2.87it/s]
# Global Step=5, Local batch=7, lose=3524.6802
#  75%|███████▌  | 9/12 [00:03<00:01,  2.79it/s]
# Global Step=5, Local batch=8, lose=3462.2693
#  83%|████████▎ | 10/12 [00:03<00:00,  2.93it/s]
# Global Step=5, Local batch=9, lose=3488.1179
#  92%|█████████▏| 11/12 [00:03<00:00,  2.82it/s]
# Global Step=5, Local batch=10, lose=3415.9556
# 100%|██████████| 12/12 [00:04<00:00,  2.86it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=5, Local batch=11, lose=3420.9092
#   8%|▊         | 1/12 [00:00<00:04,  2.67it/s]
# Global Step=6, Local batch=0, lose=3388.1001
#  17%|█▋        | 2/12 [00:00<00:03,  2.67it/s]
# Global Step=6, Local batch=1, lose=3345.4941
#  25%|██▌       | 3/12 [00:01<00:03,  2.83it/s]
# Global Step=6, Local batch=2, lose=3361.0823
#  33%|███▎      | 4/12 [00:01<00:02,  2.77it/s]
# Global Step=6, Local batch=3, lose=3291.8528
#  42%|████▏     | 5/12 [00:01<00:02,  2.92it/s]
# Global Step=6, Local batch=4, lose=3313.5728
#  50%|█████     | 6/12 [00:02<00:02,  2.84it/s]
# Global Step=6, Local batch=5, lose=3246.9277
#  58%|█████▊    | 7/12 [00:02<00:01,  2.71it/s]
# Global Step=6, Local batch=6, lose=3220.7202
#  67%|██████▋   | 8/12 [00:02<00:01,  2.87it/s]
# Global Step=6, Local batch=7, lose=3233.1226
#  75%|███████▌  | 9/12 [00:03<00:01,  2.81it/s]
# Global Step=6, Local batch=8, lose=3197.3770
#  83%|████████▎ | 10/12 [00:03<00:00,  2.93it/s]
# Global Step=6, Local batch=9, lose=3219.6631
#  92%|█████████▏| 11/12 [00:03<00:00,  2.78it/s]
# Global Step=6, Local batch=10, lose=3165.6829
# 100%|██████████| 12/12 [00:04<00:00,  2.91it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=6, Local batch=11, lose=3176.1375
#   8%|▊         | 1/12 [00:00<00:04,  2.63it/s]
# Global Step=7, Local batch=0, lose=3148.5701
#  17%|█▋        | 2/12 [00:00<00:03,  2.64it/s]
# Global Step=7, Local batch=1, lose=3107.7471
#  25%|██▌       | 3/12 [00:01<00:03,  2.82it/s]
# Global Step=7, Local batch=2, lose=3124.8870
#  33%|███▎      | 4/12 [00:01<00:02,  2.78it/s]
# Global Step=7, Local batch=3, lose=3090.6511
#  42%|████▏     | 5/12 [00:01<00:02,  2.92it/s]
# Global Step=7, Local batch=4, lose=3096.0557
#  50%|█████     | 6/12 [00:02<00:02,  2.84it/s]
# Global Step=7, Local batch=5, lose=3041.4111
#  58%|█████▊    | 7/12 [00:02<00:01,  2.77it/s]
# Global Step=7, Local batch=6, lose=3037.8972
#  67%|██████▋   | 8/12 [00:02<00:01,  2.92it/s]
# Global Step=7, Local batch=7, lose=3043.3940
#  75%|███████▌  | 9/12 [00:03<00:01,  2.84it/s]
# Global Step=7, Local batch=8, lose=3012.0002
#  83%|████████▎ | 10/12 [00:03<00:00,  2.97it/s]
# Global Step=7, Local batch=9, lose=3037.1606
#  92%|█████████▏| 11/12 [00:03<00:00,  2.86it/s]
# Global Step=7, Local batch=10, lose=2995.5037
# 100%|██████████| 12/12 [00:04<00:00,  2.98it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=7, Local batch=11, lose=3004.8259
#   8%|▊         | 1/12 [00:00<00:04,  2.64it/s]
# Global Step=8, Local batch=0, lose=2981.6973
#  17%|█▋        | 2/12 [00:00<00:03,  2.61it/s]
# Global Step=8, Local batch=1, lose=2943.6118
#  25%|██▌       | 3/12 [00:01<00:03,  2.78it/s]
# Global Step=8, Local batch=2, lose=2963.8838
#  33%|███▎      | 4/12 [00:01<00:02,  2.70it/s]
# Global Step=8, Local batch=3, lose=2941.9629
#  42%|████▏     | 5/12 [00:01<00:02,  2.79it/s]
# Global Step=8, Local batch=4, lose=2957.6841
#  50%|█████     | 6/12 [00:02<00:02,  2.67it/s]
# Global Step=8, Local batch=5, lose=2886.0659
#  58%|█████▊    | 7/12 [00:02<00:01,  2.83it/s]
# Global Step=8, Local batch=6, lose=2897.4153
#  67%|██████▋   | 8/12 [00:02<00:01,  2.95it/s]
# Global Step=8, Local batch=7, lose=2920.4905
#  75%|███████▌  | 9/12 [00:03<00:01,  2.84it/s]
# Global Step=8, Local batch=8, lose=2881.4297
#  83%|████████▎ | 10/12 [00:03<00:00,  2.96it/s]
# Global Step=8, Local batch=9, lose=2896.3774
#  92%|█████████▏| 11/12 [00:03<00:00,  2.85it/s]
# Global Step=8, Local batch=10, lose=2871.5793
# 100%|██████████| 12/12 [00:04<00:00,  2.77it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=8, Local batch=11, lose=2864.5715
#   8%|▊         | 1/12 [00:00<00:04,  2.60it/s]
# Global Step=9, Local batch=0, lose=2849.9763
#  17%|█▋        | 2/12 [00:00<00:03,  2.62it/s]
# Global Step=9, Local batch=1, lose=2816.3152
#  25%|██▌       | 3/12 [00:01<00:03,  2.79it/s]
# Global Step=9, Local batch=2, lose=2825.2061
#  33%|███▎      | 4/12 [00:01<00:02,  2.74it/s]
# Global Step=9, Local batch=3, lose=2813.2654
#  42%|████▏     | 5/12 [00:01<00:02,  2.88it/s]
# Global Step=9, Local batch=4, lose=2852.7935
#  50%|█████     | 6/12 [00:02<00:02,  2.79it/s]
# Global Step=9, Local batch=5, lose=2760.1316
#  58%|█████▊    | 7/12 [00:02<00:01,  2.92it/s]
# Global Step=9, Local batch=6, lose=2768.1499
#  67%|██████▋   | 8/12 [00:02<00:01,  3.00it/s]
# Global Step=9, Local batch=7, lose=2808.2419
#  75%|███████▌  | 9/12 [00:03<00:00,  3.09it/s]
# Global Step=9, Local batch=8, lose=2769.4243
#  83%|████████▎ | 10/12 [00:03<00:00,  3.14it/s]
# Global Step=9, Local batch=9, lose=2764.7310
#  92%|█████████▏| 11/12 [00:03<00:00,  2.96it/s]
# Global Step=9, Local batch=10, lose=2744.1721
# 100%|██████████| 12/12 [00:04<00:00,  2.84it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=9, Local batch=11, lose=2740.4731
#   8%|▊         | 1/12 [00:00<00:04,  2.60it/s]
# Global Step=10, Local batch=0, lose=2714.2485
#  17%|█▋        | 2/12 [00:00<00:03,  2.61it/s]
# Global Step=10, Local batch=1, lose=2684.4875
#  25%|██▌       | 3/12 [00:01<00:03,  2.77it/s]
# Global Step=10, Local batch=2, lose=2710.1790
#  33%|███▎      | 4/12 [00:01<00:02,  2.73it/s]
# Global Step=10, Local batch=3, lose=2670.8660
#  42%|████▏     | 5/12 [00:01<00:02,  2.89it/s]
# Global Step=10, Local batch=4, lose=2710.6265
#  50%|█████     | 6/12 [00:02<00:02,  2.80it/s]
# Global Step=10, Local batch=5, lose=2644.1831
#  58%|█████▊    | 7/12 [00:02<00:01,  2.68it/s]
# Global Step=10, Local batch=6, lose=2641.7454
#  67%|██████▋   | 8/12 [00:02<00:01,  2.77it/s]
# Global Step=10, Local batch=7, lose=2652.9309
#  75%|███████▌  | 9/12 [00:03<00:01,  2.87it/s]
# Global Step=10, Local batch=8, lose=2675.7668
#  83%|████████▎ | 10/12 [00:03<00:00,  2.95it/s]
# Global Step=10, Local batch=9, lose=2690.7029
#  92%|█████████▏| 11/12 [00:03<00:00,  2.74it/s]
# Global Step=10, Local batch=10, lose=2601.2444
# 100%|██████████| 12/12 [00:04<00:00,  2.83it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=10, Local batch=11, lose=2637.6707
#   8%|▊         | 1/12 [00:00<00:03,  3.13it/s]
# Global Step=11, Local batch=0, lose=2635.1953
#  17%|█▋        | 2/12 [00:00<00:03,  2.89it/s]
# Global Step=11, Local batch=1, lose=2550.3013
#  25%|██▌       | 3/12 [00:01<00:03,  2.93it/s]
# Global Step=11, Local batch=2, lose=2602.2886
#  33%|███▎      | 4/12 [00:01<00:02,  2.99it/s]
# Global Step=11, Local batch=3, lose=2598.5562
#  42%|████▏     | 5/12 [00:01<00:02,  3.08it/s]
# Global Step=11, Local batch=4, lose=2570.3364
#  50%|█████     | 6/12 [00:02<00:02,  2.94it/s]
# Global Step=11, Local batch=5, lose=2537.7896
#  58%|█████▊    | 7/12 [00:02<00:01,  3.02it/s]
# Global Step=11, Local batch=6, lose=2574.7788
#  67%|██████▋   | 8/12 [00:02<00:01,  2.89it/s]
# Global Step=11, Local batch=7, lose=2527.7354
#  75%|███████▌  | 9/12 [00:03<00:00,  3.00it/s]
# Global Step=11, Local batch=8, lose=2608.7905
#  83%|████████▎ | 10/12 [00:03<00:00,  3.08it/s]
# Global Step=11, Local batch=9, lose=2625.8010
#  92%|█████████▏| 11/12 [00:03<00:00,  2.92it/s]
# Global Step=11, Local batch=10, lose=2494.4541
# 100%|██████████| 12/12 [00:04<00:00,  3.02it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=11, Local batch=11, lose=2608.9783
#   8%|▊         | 1/12 [00:00<00:03,  3.31it/s]
# Global Step=12, Local batch=0, lose=2536.6213
#  17%|█▋        | 2/12 [00:00<00:03,  3.06it/s]
# Global Step=12, Local batch=1, lose=2480.0520
#  25%|██▌       | 3/12 [00:00<00:02,  3.12it/s]
# Global Step=12, Local batch=2, lose=2576.2283
#  33%|███▎      | 4/12 [00:01<00:02,  2.97it/s]
# Global Step=12, Local batch=3, lose=2458.6604
#  42%|████▏     | 5/12 [00:01<00:02,  3.06it/s]
# Global Step=12, Local batch=4, lose=2542.7036
#  50%|█████     | 6/12 [00:02<00:02,  2.92it/s]
# Global Step=12, Local batch=5, lose=2436.2063
#  58%|█████▊    | 7/12 [00:02<00:01,  3.02it/s]
# Global Step=12, Local batch=6, lose=2449.3821
#  67%|██████▋   | 8/12 [00:02<00:01,  3.09it/s]
# Global Step=12, Local batch=7, lose=2503.3845
#  75%|███████▌  | 9/12 [00:03<00:01,  2.94it/s]
# Global Step=12, Local batch=8, lose=2428.2637
#  83%|████████▎ | 10/12 [00:03<00:00,  3.03it/s]
# Global Step=12, Local batch=9, lose=2502.5742
#  92%|█████████▏| 11/12 [00:03<00:00,  2.88it/s]
# Global Step=12, Local batch=10, lose=2413.1316
# 100%|██████████| 12/12 [00:04<00:00,  2.98it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=12, Local batch=11, lose=2443.9077
#   8%|▊         | 1/12 [00:00<00:03,  3.27it/s]
# Global Step=13, Local batch=0, lose=2417.1323
#  17%|█▋        | 2/12 [00:00<00:03,  3.04it/s]
# Global Step=13, Local batch=1, lose=2366.9172
#  25%|██▌       | 3/12 [00:00<00:02,  3.10it/s]
# Global Step=13, Local batch=2, lose=2417.6189
#  33%|███▎      | 4/12 [00:01<00:02,  3.15it/s]
# Global Step=13, Local batch=3, lose=2371.3860
#  42%|████▏     | 5/12 [00:01<00:02,  3.21it/s]
# Global Step=13, Local batch=4, lose=2404.8086
#  50%|█████     | 6/12 [00:01<00:01,  3.01it/s]
# Global Step=13, Local batch=5, lose=2330.4482
#  58%|█████▊    | 7/12 [00:02<00:01,  3.07it/s]
# Global Step=13, Local batch=6, lose=2354.9551
#  67%|██████▋   | 8/12 [00:02<00:01,  3.09it/s]
# Global Step=13, Local batch=7, lose=2361.9634
#  75%|███████▌  | 9/12 [00:02<00:00,  3.10it/s]
# Global Step=13, Local batch=8, lose=2357.6228
#  83%|████████▎ | 10/12 [00:03<00:00,  3.11it/s]
# Global Step=13, Local batch=9, lose=2382.9690
#  92%|█████████▏| 11/12 [00:03<00:00,  3.08it/s]
# Global Step=13, Local batch=10, lose=2330.7192
# 100%|██████████| 12/12 [00:03<00:00,  3.08it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=13, Local batch=11, lose=2339.5251
#   8%|▊         | 1/12 [00:00<00:04,  2.42it/s]
# Global Step=14, Local batch=0, lose=2329.8904
#  17%|█▋        | 2/12 [00:00<00:04,  2.41it/s]
# Global Step=14, Local batch=1, lose=2287.7190
#  25%|██▌       | 3/12 [00:01<00:03,  2.57it/s]
# Global Step=14, Local batch=2, lose=2324.2273
#  33%|███▎      | 4/12 [00:01<00:02,  2.70it/s]
# Global Step=14, Local batch=3, lose=2306.7974
#  42%|████▏     | 5/12 [00:01<00:02,  2.79it/s]
# Global Step=14, Local batch=4, lose=2329.1738
#  50%|█████     | 6/12 [00:02<00:02,  2.65it/s]
# Global Step=14, Local batch=5, lose=2272.5435
#  58%|█████▊    | 7/12 [00:02<00:01,  2.75it/s]
# Global Step=14, Local batch=6, lose=2290.5408
#  67%|██████▋   | 8/12 [00:02<00:01,  2.84it/s]
# Global Step=14, Local batch=7, lose=2309.9258
#  75%|███████▌  | 9/12 [00:03<00:01,  2.92it/s]
# Global Step=14, Local batch=8, lose=2317.6157
#  83%|████████▎ | 10/12 [00:03<00:00,  3.02it/s]
# Global Step=14, Local batch=9, lose=2314.4937
#  92%|█████████▏| 11/12 [00:03<00:00,  2.79it/s]
# Global Step=14, Local batch=10, lose=2271.0054
# 100%|██████████| 12/12 [00:04<00:00,  2.92it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=14, Local batch=11, lose=2287.1636
#   8%|▊         | 1/12 [00:00<00:04,  2.62it/s]
# Global Step=15, Local batch=0, lose=2266.4600
#  17%|█▋        | 2/12 [00:00<00:03,  2.62it/s]
# Global Step=15, Local batch=1, lose=2229.8638
#  25%|██▌       | 3/12 [00:01<00:03,  2.79it/s]
# Global Step=15, Local batch=2, lose=2267.5125
#  33%|███▎      | 4/12 [00:01<00:02,  2.92it/s]
# Global Step=15, Local batch=3, lose=2251.6028
#  42%|████▏     | 5/12 [00:01<00:02,  3.03it/s]
# Global Step=15, Local batch=4, lose=2270.8950
#  50%|█████     | 6/12 [00:02<00:02,  2.91it/s]
# Global Step=15, Local batch=5, lose=2227.0413
#  58%|█████▊    | 7/12 [00:02<00:01,  3.01it/s]
# Global Step=15, Local batch=6, lose=2241.5693
#  67%|██████▋   | 8/12 [00:02<00:01,  3.12it/s]
# Global Step=15, Local batch=7, lose=2246.5789
#  75%|███████▌  | 9/12 [00:02<00:00,  3.17it/s]
# Global Step=15, Local batch=8, lose=2280.5139
#  83%|████████▎ | 10/12 [00:03<00:00,  3.20it/s]
# Global Step=15, Local batch=9, lose=2293.9143
#  92%|█████████▏| 11/12 [00:03<00:00,  3.00it/s]
# Global Step=15, Local batch=10, lose=2215.8792
# 100%|██████████| 12/12 [00:03<00:00,  3.08it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=15, Local batch=11, lose=2248.3318
#   8%|▊         | 1/12 [00:00<00:03,  3.31it/s]
# Global Step=16, Local batch=0, lose=2247.2793
#  17%|█▋        | 2/12 [00:00<00:03,  3.07it/s]
# Global Step=16, Local batch=1, lose=2177.4187
#  25%|██▌       | 3/12 [00:00<00:02,  3.12it/s]
# Global Step=16, Local batch=2, lose=2239.1255
#  33%|███▎      | 4/12 [00:01<00:02,  3.16it/s]
# Global Step=16, Local batch=3, lose=2241.9399
#  42%|████▏     | 5/12 [00:01<00:02,  3.21it/s]
# Global Step=16, Local batch=4, lose=2217.7344
#  50%|█████     | 6/12 [00:01<00:01,  3.23it/s]
# Global Step=16, Local batch=5, lose=2214.4202
#  58%|█████▊    | 7/12 [00:02<00:01,  3.26it/s]
# Global Step=16, Local batch=6, lose=2238.7148
#  67%|██████▋   | 8/12 [00:02<00:01,  3.27it/s]
# Global Step=16, Local batch=7, lose=2202.0122
#  75%|███████▌  | 9/12 [00:02<00:00,  3.28it/s]
# Global Step=16, Local batch=8, lose=2299.9890
#  83%|████████▎ | 10/12 [00:03<00:00,  3.29it/s]
# Global Step=16, Local batch=9, lose=2302.1394
#  92%|█████████▏| 11/12 [00:03<00:00,  3.31it/s]
# Global Step=16, Local batch=10, lose=2184.5330
# 100%|██████████| 12/12 [00:03<00:00,  3.32it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=16, Local batch=11, lose=2293.2227
#   8%|▊         | 1/12 [00:00<00:03,  3.32it/s]
# Global Step=17, Local batch=0, lose=2218.3262
#  17%|█▋        | 2/12 [00:00<00:03,  3.31it/s]
# Global Step=17, Local batch=1, lose=2183.4683
#  25%|██▌       | 3/12 [00:00<00:02,  3.30it/s]
# Global Step=17, Local batch=2, lose=2255.3528
#  33%|███▎      | 4/12 [00:01<00:02,  3.08it/s]
# Global Step=17, Local batch=3, lose=2171.3130
#  42%|████▏     | 5/12 [00:01<00:02,  3.15it/s]
# Global Step=17, Local batch=4, lose=2247.9021
#  50%|█████     | 6/12 [00:01<00:02,  2.98it/s]
# Global Step=17, Local batch=5, lose=2150.4202
#  58%|█████▊    | 7/12 [00:02<00:01,  3.06it/s]
# Global Step=17, Local batch=6, lose=2182.0356
#  67%|██████▋   | 8/12 [00:02<00:01,  3.14it/s]
# Global Step=17, Local batch=7, lose=2218.5730
#  75%|███████▌  | 9/12 [00:02<00:00,  3.19it/s]
# Global Step=17, Local batch=8, lose=2163.7688
#  83%|████████▎ | 10/12 [00:03<00:00,  3.23it/s]
# Global Step=17, Local batch=9, lose=2228.7617
#  92%|█████████▏| 11/12 [00:03<00:00,  3.01it/s]
# Global Step=17, Local batch=10, lose=2148.3933
# 100%|██████████| 12/12 [00:03<00:00,  3.06it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=17, Local batch=11, lose=2176.3000
#   8%|▊         | 1/12 [00:00<00:03,  3.32it/s]
# Global Step=18, Local batch=0, lose=2156.6716
#  17%|█▋        | 2/12 [00:00<00:03,  3.07it/s]
# Global Step=18, Local batch=1, lose=2112.2710
#  25%|██▌       | 3/12 [00:00<00:02,  3.11it/s]
# Global Step=18, Local batch=2, lose=2154.5842
#  33%|███▎      | 4/12 [00:01<00:02,  3.17it/s]
# Global Step=18, Local batch=3, lose=2136.2288
#  42%|████▏     | 5/12 [00:01<00:02,  3.20it/s]
# Global Step=18, Local batch=4, lose=2158.8733
#  50%|█████     | 6/12 [00:01<00:02,  3.00it/s]
# Global Step=18, Local batch=5, lose=2101.8645
#  58%|█████▊    | 7/12 [00:02<00:01,  3.07it/s]
# Global Step=18, Local batch=6, lose=2125.5522
#  67%|██████▋   | 8/12 [00:02<00:01,  3.14it/s]
# Global Step=18, Local batch=7, lose=2127.8037
#  75%|███████▌  | 9/12 [00:02<00:00,  3.19it/s]
# Global Step=18, Local batch=8, lose=2130.3142
#  83%|████████▎ | 10/12 [00:03<00:00,  3.23it/s]
# Global Step=18, Local batch=9, lose=2154.1013
#  92%|█████████▏| 11/12 [00:03<00:00,  3.26it/s]
# Global Step=18, Local batch=10, lose=2105.9993
# 100%|██████████| 12/12 [00:03<00:00,  3.27it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=18, Local batch=11, lose=2119.4260
#   8%|▊         | 1/12 [00:00<00:03,  3.32it/s]
# Global Step=19, Local batch=0, lose=2105.3022
#  17%|█▋        | 2/12 [00:00<00:03,  3.08it/s]
# Global Step=19, Local batch=1, lose=2072.6226
#  25%|██▌       | 3/12 [00:00<00:02,  3.14it/s]
# Global Step=19, Local batch=2, lose=2101.9463
#  33%|███▎      | 4/12 [00:01<00:02,  3.19it/s]
# Global Step=19, Local batch=3, lose=2098.5400
#  42%|████▏     | 5/12 [00:01<00:02,  3.23it/s]
# Global Step=19, Local batch=4, lose=2120.1208
#  50%|█████     | 6/12 [00:01<00:02,  2.97it/s]
# Global Step=19, Local batch=5, lose=2071.5134
#  58%|█████▊    | 7/12 [00:02<00:01,  3.05it/s]
# Global Step=19, Local batch=6, lose=2089.5581
#  67%|██████▋   | 8/12 [00:02<00:01,  3.12it/s]
# Global Step=19, Local batch=7, lose=2107.8271
#  75%|███████▌  | 9/12 [00:02<00:00,  3.17it/s]
# Global Step=19, Local batch=8, lose=2102.2000
#  83%|████████▎ | 10/12 [00:03<00:00,  3.21it/s]
# Global Step=19, Local batch=9, lose=2118.9487
#  92%|█████████▏| 11/12 [00:03<00:00,  3.21it/s]
# Global Step=19, Local batch=10, lose=2076.0422
# 100%|██████████| 12/12 [00:03<00:00,  3.24it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=19, Local batch=11, lose=2079.7532
#   8%|▊         | 1/12 [00:00<00:04,  2.62it/s]
# Global Step=20, Local batch=0, lose=2070.2937
#  17%|█▋        | 2/12 [00:00<00:03,  2.62it/s]
# Global Step=20, Local batch=1, lose=2039.9186
#  25%|██▌       | 3/12 [00:01<00:03,  2.79it/s]
# Global Step=20, Local batch=2, lose=2058.2061
#  33%|███▎      | 4/12 [00:01<00:02,  2.93it/s]
# Global Step=20, Local batch=3, lose=2061.8933
#  42%|████▏     | 5/12 [00:01<00:02,  3.02it/s]
# Global Step=20, Local batch=4, lose=2076.8657
#  50%|█████     | 6/12 [00:02<00:02,  2.88it/s]
# Global Step=20, Local batch=5, lose=2028.8732
#  58%|█████▊    | 7/12 [00:02<00:01,  2.99it/s]
# Global Step=20, Local batch=6, lose=2046.7360
#  67%|██████▋   | 8/12 [00:02<00:01,  3.07it/s]
# Global Step=20, Local batch=7, lose=2058.1355
#  75%|███████▌  | 9/12 [00:02<00:00,  3.13it/s]
# Global Step=20, Local batch=8, lose=2055.9470
#  83%|████████▎ | 10/12 [00:03<00:00,  3.19it/s]
# Global Step=20, Local batch=9, lose=2088.1362
#  92%|█████████▏| 11/12 [00:03<00:00,  3.23it/s]
# Global Step=20, Local batch=10, lose=2046.7594
# 100%|██████████| 12/12 [00:03<00:00,  3.25it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=20, Local batch=11, lose=2036.1172
#   8%|▊         | 1/12 [00:00<00:04,  2.63it/s]
# Global Step=21, Local batch=0, lose=2024.0114
#  17%|█▋        | 2/12 [00:00<00:03,  2.62it/s]
# Global Step=21, Local batch=1, lose=2004.9514
#  25%|██▌       | 3/12 [00:01<00:03,  2.76it/s]
# Global Step=21, Local batch=2, lose=2025.2698
#  33%|███▎      | 4/12 [00:01<00:02,  2.89it/s]
# Global Step=21, Local batch=3, lose=2027.0802
#  42%|████▏     | 5/12 [00:01<00:02,  3.00it/s]
# Global Step=21, Local batch=4, lose=2040.2092
#  50%|█████     | 6/12 [00:02<00:02,  2.88it/s]
# Global Step=21, Local batch=5, lose=1989.3472
#  58%|█████▊    | 7/12 [00:02<00:01,  2.98it/s]
# Global Step=21, Local batch=6, lose=2002.0159
#  67%|██████▋   | 8/12 [00:02<00:01,  3.07it/s]
# Global Step=21, Local batch=7, lose=2024.1069
#  75%|███████▌  | 9/12 [00:02<00:00,  3.14it/s]
# Global Step=21, Local batch=8, lose=2035.6442
#  83%|████████▎ | 10/12 [00:03<00:00,  3.19it/s]
# Global Step=21, Local batch=9, lose=2072.8335
#  92%|█████████▏| 11/12 [00:03<00:00,  3.12it/s]
# Global Step=21, Local batch=10, lose=2023.3669
# 100%|██████████| 12/12 [00:03<00:00,  3.17it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=21, Local batch=11, lose=2007.6155
#   8%|▊         | 1/12 [00:00<00:04,  2.61it/s]
# Global Step=22, Local batch=0, lose=1984.2231
#  17%|█▋        | 2/12 [00:00<00:03,  2.60it/s]
# Global Step=22, Local batch=1, lose=1968.4955
#  25%|██▌       | 3/12 [00:01<00:03,  2.77it/s]
# Global Step=22, Local batch=2, lose=2003.0106
#  33%|███▎      | 4/12 [00:01<00:02,  2.91it/s]
# Global Step=22, Local batch=3, lose=2010.1124
#  42%|████▏     | 5/12 [00:01<00:02,  3.02it/s]
# Global Step=22, Local batch=4, lose=2026.5081
#  50%|█████     | 6/12 [00:01<00:01,  3.09it/s]
# Global Step=22, Local batch=5, lose=1980.3921
#  58%|█████▊    | 7/12 [00:02<00:01,  3.14it/s]
# Global Step=22, Local batch=6, lose=1984.4785
#  67%|██████▋   | 8/12 [00:02<00:01,  3.18it/s]
# Global Step=22, Local batch=7, lose=1987.2513
#  75%|███████▌  | 9/12 [00:02<00:00,  3.21it/s]
# Global Step=22, Local batch=8, lose=2007.2782
#  83%|████████▎ | 10/12 [00:03<00:00,  3.24it/s]
# Global Step=22, Local batch=9, lose=2064.9658
#  92%|█████████▏| 11/12 [00:03<00:00,  3.25it/s]
# Global Step=22, Local batch=10, lose=1986.0400
# 100%|██████████| 12/12 [00:03<00:00,  3.04it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=22, Local batch=11, lose=1964.5425
#   8%|▊         | 1/12 [00:00<00:03,  3.18it/s]
# Global Step=23, Local batch=0, lose=1968.7908
#  17%|█▋        | 2/12 [00:00<00:03,  2.97it/s]
# Global Step=23, Local batch=1, lose=1953.9713
#  25%|██▌       | 3/12 [00:01<00:03,  2.99it/s]
# Global Step=23, Local batch=2, lose=1968.4968
#  33%|███▎      | 4/12 [00:01<00:02,  3.05it/s]
# Global Step=23, Local batch=3, lose=1957.7980
#  42%|████▏     | 5/12 [00:01<00:02,  3.13it/s]
# Global Step=23, Local batch=4, lose=1963.0410
#  50%|█████     | 6/12 [00:02<00:02,  2.90it/s]
# Global Step=23, Local batch=5, lose=1925.4839
#  58%|█████▊    | 7/12 [00:02<00:01,  3.00it/s]
# Global Step=23, Local batch=6, lose=1940.5242
#  67%|██████▋   | 8/12 [00:02<00:01,  3.08it/s]
# Global Step=23, Local batch=7, lose=1954.3699
#  75%|███████▌  | 9/12 [00:02<00:00,  3.13it/s]
# Global Step=23, Local batch=8, lose=1953.2601
#  83%|████████▎ | 10/12 [00:03<00:00,  3.18it/s]
# Global Step=23, Local batch=9, lose=1978.6832
#  92%|█████████▏| 11/12 [00:03<00:00,  3.22it/s]
# Global Step=23, Local batch=10, lose=1933.5079
# 100%|██████████| 12/12 [00:03<00:00,  3.24it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=23, Local batch=11, lose=1929.3995
#   8%|▊         | 1/12 [00:00<00:04,  2.60it/s]
# Global Step=24, Local batch=0, lose=1918.2607
#  17%|█▋        | 2/12 [00:00<00:03,  2.60it/s]
# Global Step=24, Local batch=1, lose=1896.4502
#  25%|██▌       | 3/12 [00:01<00:03,  2.77it/s]
# Global Step=24, Local batch=2, lose=1916.4518
#  33%|███▎      | 4/12 [00:01<00:02,  2.91it/s]
# Global Step=24, Local batch=3, lose=1928.9733
#  42%|████▏     | 5/12 [00:01<00:02,  3.02it/s]
# Global Step=24, Local batch=4, lose=1950.3501
#  50%|█████     | 6/12 [00:01<00:01,  3.11it/s]
# Global Step=24, Local batch=5, lose=1918.0165
#  58%|█████▊    | 7/12 [00:02<00:01,  3.03it/s]
# Global Step=24, Local batch=6, lose=1930.8671
#  67%|██████▋   | 8/12 [00:02<00:01,  3.06it/s]
# Global Step=24, Local batch=7, lose=1925.1254
#  75%|███████▌  | 9/12 [00:02<00:00,  3.13it/s]
# Global Step=24, Local batch=8, lose=1916.5735
#  83%|████████▎ | 10/12 [00:03<00:00,  3.16it/s]
# Global Step=24, Local batch=9, lose=1964.8555
#  92%|█████████▏| 11/12 [00:03<00:00,  3.16it/s]
# Global Step=24, Local batch=10, lose=1947.9786
# 100%|██████████| 12/12 [00:03<00:00,  3.10it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=24, Local batch=11, lose=1968.8143
#   8%|▊         | 1/12 [00:00<00:03,  3.23it/s]
# Global Step=25, Local batch=0, lose=1906.2175
#  17%|█▋        | 2/12 [00:00<00:03,  2.88it/s]
# Global Step=25, Local batch=1, lose=1865.5697
#  25%|██▌       | 3/12 [00:01<00:03,  2.97it/s]
# Global Step=25, Local batch=2, lose=1900.8055
#  33%|███▎      | 4/12 [00:01<00:02,  3.04it/s]
# Global Step=25, Local batch=3, lose=1939.2646
#  42%|████▏     | 5/12 [00:01<00:02,  3.09it/s]
# Global Step=25, Local batch=4, lose=1977.8645
#  50%|█████     | 6/12 [00:01<00:01,  3.14it/s]
# Global Step=25, Local batch=5, lose=1895.4624
#  58%|█████▊    | 7/12 [00:02<00:01,  3.18it/s]
# Global Step=25, Local batch=6, lose=1875.5684
#  67%|██████▋   | 8/12 [00:02<00:01,  3.20it/s]
# Global Step=25, Local batch=7, lose=1917.6041
#  75%|███████▌  | 9/12 [00:02<00:00,  3.23it/s]
# Global Step=25, Local batch=8, lose=1947.3824
#  83%|████████▎ | 10/12 [00:03<00:00,  3.23it/s]
# Global Step=25, Local batch=9, lose=1966.9847
#  92%|█████████▏| 11/12 [00:03<00:00,  3.24it/s]
# Global Step=25, Local batch=10, lose=1866.7946
# 100%|██████████| 12/12 [00:03<00:00,  3.25it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=25, Local batch=11, lose=1898.3932
#   8%|▊         | 1/12 [00:00<00:03,  3.23it/s]
# Global Step=26, Local batch=0, lose=1926.8712
#  17%|█▋        | 2/12 [00:00<00:03,  3.03it/s]
# Global Step=26, Local batch=1, lose=1845.0698
#  25%|██▌       | 3/12 [00:00<00:02,  3.09it/s]
# Global Step=26, Local batch=2, lose=1878.6348
#  33%|███▎      | 4/12 [00:01<00:02,  3.14it/s]
# Global Step=26, Local batch=3, lose=1919.6235
#  42%|████▏     | 5/12 [00:01<00:02,  3.17it/s]
# Global Step=26, Local batch=4, lose=1873.2510
#  50%|█████     | 6/12 [00:01<00:01,  3.11it/s]
# Global Step=26, Local batch=5, lose=1894.5967
#  58%|█████▊    | 7/12 [00:02<00:01,  3.12it/s]
# Global Step=26, Local batch=6, lose=1941.3739
#  67%|██████▋   | 8/12 [00:02<00:01,  3.13it/s]
# Global Step=26, Local batch=7, lose=1869.6022
#  75%|███████▌  | 9/12 [00:02<00:00,  3.14it/s]
# Global Step=26, Local batch=8, lose=1991.9171
#  83%|████████▎ | 10/12 [00:03<00:00,  3.16it/s]
# Global Step=26, Local batch=9, lose=2050.6663
#  92%|█████████▏| 11/12 [00:03<00:00,  3.19it/s]
# Global Step=26, Local batch=10, lose=1862.9365
# 100%|██████████| 12/12 [00:03<00:00,  3.21it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=26, Local batch=11, lose=2075.2732
#   8%|▊         | 1/12 [00:00<00:03,  3.33it/s]
# Global Step=27, Local batch=0, lose=1995.7767
#  17%|█▋        | 2/12 [00:00<00:03,  3.32it/s]
# Global Step=27, Local batch=1, lose=1954.3401
#  25%|██▌       | 3/12 [00:00<00:02,  3.31it/s]
# Global Step=27, Local batch=2, lose=2017.1801
#  33%|███▎      | 4/12 [00:01<00:02,  3.30it/s]
# Global Step=27, Local batch=3, lose=1897.6096
#  42%|████▏     | 5/12 [00:01<00:02,  3.28it/s]
# Global Step=27, Local batch=4, lose=2008.1415
#  50%|█████     | 6/12 [00:01<00:01,  3.21it/s]
# Global Step=27, Local batch=5, lose=1850.0140
#  58%|█████▊    | 7/12 [00:02<00:01,  3.17it/s]
# Global Step=27, Local batch=6, lose=1967.2311
#  67%|██████▋   | 8/12 [00:02<00:01,  3.22it/s]
# Global Step=27, Local batch=7, lose=1890.9636
#  75%|███████▌  | 9/12 [00:02<00:00,  3.16it/s]
# Global Step=27, Local batch=8, lose=1916.3894
#  83%|████████▎ | 10/12 [00:03<00:00,  3.19it/s]
# Global Step=27, Local batch=9, lose=1892.8284
#  92%|█████████▏| 11/12 [00:03<00:00,  3.17it/s]
# Global Step=27, Local batch=10, lose=1903.1737
# 100%|██████████| 12/12 [00:03<00:00,  3.18it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=27, Local batch=11, lose=1852.3055
#   8%|▊         | 1/12 [00:00<00:03,  3.24it/s]
# Global Step=28, Local batch=0, lose=1887.9691
#  17%|█▋        | 2/12 [00:00<00:03,  2.98it/s]
# Global Step=28, Local batch=1, lose=1812.9661
#  25%|██▌       | 3/12 [00:01<00:02,  3.01it/s]
# Global Step=28, Local batch=2, lose=1879.0321
#  33%|███▎      | 4/12 [00:01<00:02,  3.06it/s]
# Global Step=28, Local batch=3, lose=1829.5441
#  42%|████▏     | 5/12 [00:01<00:02,  3.08it/s]
# Global Step=28, Local batch=4, lose=1890.5101
#  50%|█████     | 6/12 [00:02<00:02,  2.86it/s]
# Global Step=28, Local batch=5, lose=1805.8647
#  58%|█████▊    | 7/12 [00:02<00:01,  2.89it/s]
# Global Step=28, Local batch=6, lose=1862.2137
#  67%|██████▋   | 8/12 [00:02<00:01,  2.96it/s]
# Global Step=28, Local batch=7, lose=1826.3728
#  75%|███████▌  | 9/12 [00:03<00:01,  2.99it/s]
# Global Step=28, Local batch=8, lose=1848.9182
#  83%|████████▎ | 10/12 [00:03<00:00,  3.02it/s]
# Global Step=28, Local batch=9, lose=1845.3837
#  92%|█████████▏| 11/12 [00:03<00:00,  3.04it/s]
# Global Step=28, Local batch=10, lose=1831.8486
# 100%|██████████| 12/12 [00:04<00:00,  3.05it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=28, Local batch=11, lose=1809.5122
#   8%|▊         | 1/12 [00:00<00:03,  3.06it/s]
# Global Step=29, Local batch=0, lose=1820.3418
#  17%|█▋        | 2/12 [00:00<00:03,  2.84it/s]
# Global Step=29, Local batch=1, lose=1781.6055
#  25%|██▌       | 3/12 [00:01<00:03,  2.86it/s]
# Global Step=29, Local batch=2, lose=1813.8214
#  33%|███▎      | 4/12 [00:01<00:02,  2.90it/s]
# Global Step=29, Local batch=3, lose=1802.6560
#  42%|████▏     | 5/12 [00:01<00:02,  3.00it/s]
# Global Step=29, Local batch=4, lose=1835.0372
#  50%|█████     | 6/12 [00:02<00:02,  2.87it/s]
# Global Step=29, Local batch=5, lose=1780.9122
#  58%|█████▊    | 7/12 [00:02<00:01,  2.95it/s]
# Global Step=29, Local batch=6, lose=1812.7880
#  67%|██████▋   | 8/12 [00:02<00:01,  3.00it/s]
# Global Step=29, Local batch=7, lose=1812.1439
#  75%|███████▌  | 9/12 [00:03<00:00,  3.06it/s]
# Global Step=29, Local batch=8, lose=1807.5236
#  83%|████████▎ | 10/12 [00:03<00:00,  3.10it/s]
# Global Step=29, Local batch=9, lose=1828.2975
#  92%|█████████▏| 11/12 [00:03<00:00,  3.09it/s]
# Global Step=29, Local batch=10, lose=1787.7999
# 100%|██████████| 12/12 [00:04<00:00,  3.10it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=29, Local batch=11, lose=1794.9435
#   8%|▊         | 1/12 [00:00<00:04,  2.44it/s]
# Global Step=30, Local batch=0, lose=1778.0105
#  17%|█▋        | 2/12 [00:00<00:04,  2.43it/s]
# Global Step=30, Local batch=1, lose=1767.3055
#  25%|██▌       | 3/12 [00:01<00:03,  2.59it/s]
# Global Step=30, Local batch=2, lose=1768.3833
#  33%|███▎      | 4/12 [00:01<00:02,  2.70it/s]
# Global Step=30, Local batch=3, lose=1783.7689
#  42%|████▏     | 5/12 [00:01<00:02,  2.79it/s]
# Global Step=30, Local batch=4, lose=1784.4509
#  50%|█████     | 6/12 [00:02<00:02,  2.64it/s]
# Global Step=30, Local batch=5, lose=1763.9688
#  58%|█████▊    | 7/12 [00:02<00:01,  2.75it/s]
# Global Step=30, Local batch=6, lose=1765.0284
#  67%|██████▋   | 8/12 [00:02<00:01,  2.84it/s]
# Global Step=30, Local batch=7, lose=1794.9508
#  75%|███████▌  | 9/12 [00:03<00:01,  2.90it/s]
# Global Step=30, Local batch=8, lose=1794.3850
#  83%|████████▎ | 10/12 [00:03<00:00,  2.94it/s]
# Global Step=30, Local batch=9, lose=1836.9774
#  92%|█████████▏| 11/12 [00:03<00:00,  2.97it/s]
# Global Step=30, Local batch=10, lose=1831.9955
# 100%|██████████| 12/12 [00:04<00:00,  2.98it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=30, Local batch=11, lose=1836.0929
#   8%|▊         | 1/12 [00:00<00:03,  2.98it/s]
# Global Step=31, Local batch=0, lose=1790.3297
#  17%|█▋        | 2/12 [00:00<00:03,  2.77it/s]
# Global Step=31, Local batch=1, lose=1748.6603
#  25%|██▌       | 3/12 [00:01<00:03,  2.84it/s]
# Global Step=31, Local batch=2, lose=1769.5494
#  33%|███▎      | 4/12 [00:01<00:02,  2.90it/s]
# Global Step=31, Local batch=3, lose=1790.1017
#  42%|████▏     | 5/12 [00:01<00:02,  2.93it/s]
# Global Step=31, Local batch=4, lose=1778.3669
#  50%|█████     | 6/12 [00:02<00:02,  2.73it/s]
# Global Step=31, Local batch=5, lose=1747.3058
#  58%|█████▊    | 7/12 [00:02<00:01,  2.83it/s]
# Global Step=31, Local batch=6, lose=1769.7616
#  67%|██████▋   | 8/12 [00:02<00:01,  2.88it/s]
# Global Step=31, Local batch=7, lose=1779.2960
#  75%|███████▌  | 9/12 [00:03<00:01,  2.93it/s]
# Global Step=31, Local batch=8, lose=1766.5447
#  83%|████████▎ | 10/12 [00:03<00:00,  2.95it/s]
# Global Step=31, Local batch=9, lose=1794.6580
#  92%|█████████▏| 11/12 [00:03<00:00,  2.94it/s]
# Global Step=31, Local batch=10, lose=1756.6471
# 100%|██████████| 12/12 [00:04<00:00,  2.95it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=31, Local batch=11, lose=1752.4857
#   8%|▊         | 1/12 [00:00<00:04,  2.35it/s]
# Global Step=32, Local batch=0, lose=1741.6853
#  17%|█▋        | 2/12 [00:00<00:04,  2.37it/s]
# Global Step=32, Local batch=1, lose=1733.6320
#  25%|██▌       | 3/12 [00:01<00:03,  2.53it/s]
# Global Step=32, Local batch=2, lose=1737.5935
#  33%|███▎      | 4/12 [00:01<00:03,  2.65it/s]
# Global Step=32, Local batch=3, lose=1744.0311
#  42%|████▏     | 5/12 [00:01<00:02,  2.74it/s]
# Global Step=32, Local batch=4, lose=1754.4575
#  50%|█████     | 6/12 [00:02<00:02,  2.62it/s]
# Global Step=32, Local batch=5, lose=1729.9625
#  58%|█████▊    | 7/12 [00:02<00:01,  2.74it/s]
# Global Step=32, Local batch=6, lose=1737.0046
#  67%|██████▋   | 8/12 [00:02<00:01,  2.81it/s]
# Global Step=32, Local batch=7, lose=1753.9453
#  75%|███████▌  | 9/12 [00:03<00:01,  2.87it/s]
# Global Step=32, Local batch=8, lose=1756.9760
#  83%|████████▎ | 10/12 [00:03<00:00,  2.91it/s]
# Global Step=32, Local batch=9, lose=1773.1844
#  92%|█████████▏| 11/12 [00:04<00:00,  2.71it/s]
# Global Step=32, Local batch=10, lose=1728.7157
# 100%|██████████| 12/12 [00:04<00:00,  2.79it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=32, Local batch=11, lose=1730.0226
#   8%|▊         | 1/12 [00:00<00:04,  2.34it/s]
# Global Step=33, Local batch=0, lose=1723.8326
#  17%|█▋        | 2/12 [00:00<00:04,  2.32it/s]
# Global Step=33, Local batch=1, lose=1706.6725
#  25%|██▌       | 3/12 [00:01<00:03,  2.46it/s]
# Global Step=33, Local batch=2, lose=1711.0914
#  33%|███▎      | 4/12 [00:01<00:03,  2.58it/s]
# Global Step=33, Local batch=3, lose=1727.6965
#  42%|████▏     | 5/12 [00:01<00:02,  2.67it/s]
# Global Step=33, Local batch=4, lose=1733.1903
#  50%|█████     | 6/12 [00:02<00:02,  2.73it/s]
# Global Step=33, Local batch=5, lose=1707.3605
#  58%|█████▊    | 7/12 [00:02<00:01,  2.78it/s]
# Global Step=33, Local batch=6, lose=1725.5928
#  67%|██████▋   | 8/12 [00:02<00:01,  2.83it/s]
# Global Step=33, Local batch=7, lose=1759.6619
#  75%|███████▌  | 9/12 [00:03<00:01,  2.85it/s]
# Global Step=33, Local batch=8, lose=1758.8173
#  83%|████████▎ | 10/12 [00:03<00:00,  2.88it/s]
# Global Step=33, Local batch=9, lose=1789.5887
#  92%|█████████▏| 11/12 [00:03<00:00,  2.89it/s]
# Global Step=33, Local batch=10, lose=1758.5736
# 100%|██████████| 12/12 [00:04<00:00,  2.90it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Global Step=33, Local batch=11, lose=1751.9376
#   8%|▊         | 1/12 [00:00<00:03,  2.90it/s]
# Global Step=34, Local batch=0, lose=1712.5219
#  17%|█▋        | 2/12 [00:00<00:03,  2.69it/s]
# Global Step=34, Local batch=1, lose=1697.9236
#  25%|██▌       | 3/12 [00:01<00:03,  2.72it/s]
# Global Step=34, Local batch=2, lose=1714.3143
#  33%|███▎      | 4/12 [00:01<00:02,  2.78it/s]
# Global Step=34, Local batch=3, lose=1725.3867
#  42%|████▏     | 5/12 [00:01<00:02,  2.84it/s]
# Global Step=34, Local batch=4, lose=1728.7969
#  50%|█████     | 6/12 [00:02<00:02,  2.89it/s]
# Global Step=34, Local batch=5, lose=1700.2850
#  58%|█████▊    | 7/12 [00:02<00:01,  2.98it/s]
# Global Step=34, Local batch=6, lose=1715.6044
#  67%|██████▋   | 8/12 [00:02<00:01,  3.02it/s]
# Global Step=34, Local batch=7, lose=1752.2126
#  75%|███████▌  | 9/12 [00:03<00:00,  3.06it/s]
# Global Step=34, Local batch=8, lose=1732.4504
#  83%|████████▎ | 10/12 [00:03<00:00,  3.09it/s]
# Global Step=34, Local batch=9, lose=1740.9392
#  92%|█████████▏| 11/12 [00:03<00:00,  3.10it/s]
# Global Step=34, Local batch=10, lose=1705.6575
# 100%|██████████| 12/12 [00:04<00:00,  3.12it/s]
# Global Step=34, Local batch=11, lose=1706.5986

# %%
#Test Processing:
output = []
with tf.Session() as sess:
    if os.path.exists('tmp/checkpoint'):        
        saver.restore(sess, 'tmp/model.ckpt')
        total_batch  = int(len(test_images)/batch_size)
        msg = "Test batch={:d}, lose={:.4f}"
        for b in tqdm(range(total_batch)):
            batch = test_images[b*batch_size:(b+1)*batch_size]
            imgs = batch.reshape((-1,28,28,1))
            cost,out = sess.run([loss,conv_final], feed_dict={input_x:batch})
            output.append(out)
            print(msg.format(b,cost))

    else :
        print("Please run training part first")
    fig1 = plt.figure(figsize=(8,8))
    fig1.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.5, wspace=0.05)
    for i in range(30):
        image = np.reshape(test_images[i],[28,28])
        ax=fig1.add_subplot(6,5,i+1,xticks=[],yticks=[]) 
        ax.imshow(image,cmap=plt.cm.binary,interpolation='nearest') 
        ax.text(0,7,str(test_labels[i]))
    plt.show()
    print("---------------------------------------------------")
    fig = plt.figure(figsize=(8,8))
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.5, wspace=0.05)
    for i in range(30):
        image = np.reshape(output[0][i],[28,28])
        ax=fig.add_subplot(6,5,i+1,xticks=[],yticks=[]) 
        ax.imshow(image,cmap=plt.cm.binary,interpolation='nearest') 
        ax.text(0,7,str(test_labels[i]))
    plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from tmp/model.ckpt
# 100%|██████████| 2/2 [00:00<00:00,  6.66it/s]
# Test batch=0, lose=1711.0925
# Test batch=1, lose=1702.4551
# ---------------------------------------------------
